# %%
#importing modules
import pandas as pd
dataSet = pd.read_csv('C:/Users/ADMIN/Desktop/Data Science/Real estate/Real estate.csv') #reading the csv file

# %%
dataSet
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
dataSet.head() #to view first 5 rows in dataset and default value = 5
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
dataSet.head(1) #we can pass the argument to view number of rows
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9

# %%
dataSet.tail() # to view last 5 rows of dataSet default argument is 5
# Out:
#       No  X1 transaction date  X2 house age  \
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# ...

# %%
dataSet.tail(3) # to view last 3 rows of the dataSet
# Out:
#       No  X1 transaction date  X2 house age  \
# 411  412              2013.25          18.8
# 412  413              2013.00           8.1
# 413  414              2013.50           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9

# %%
#nrows(without using head we can view the number of rows directly)
d1 = pd.read_csv('C:/Users/ADMIN/Desktop/Data Science/Real estate/Real estate.csv',nrows = 10)
d1
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
# 5   6             2012.667           7.1
# 6   7             2012.667          34.5
# 7   8             2013.417          20.3
# 8   9             2013.500          31.7
# 9  10             2013.417          17.9
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
# ...

# %%
dataSet
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
dataSet.dtypes #datatype checking
# Out:
# No                                          int64
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
dataSet['No'] #Accessing the column / Series creation
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 409    410
# 410    411
# 411    412
# 412    413
# 413    414
# Name: No, Length: 414, dtype: int64

# %%
dataSet['X2 house age'] # Accessing column using indexing
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 409    13.7
# 410     5.6
# 411    18.8
# 412     8.1
# 413     6.5
# Name: X2 house age, Length: 414, dtype: float64

# %%
list([dataSet['X2 house age'],dataSet['No']]) #Creating series of multiple columns
# Out:
# [0      32.0
#  1      19.5
#  2      13.3
#  3      13.3
#  4       5.0
#         ...
#  409    13.7
#  410     5.6
#  411    18.8
#  412     8.1
#  413     6.5
#  Name: X2 house age, Length: 414, dtype: float64,
#  0        1
#  1        2
#  2        3
#  3        4
#  4        5
#        ...
#  409    410
#  410    411
#  411    412
#  412    413
#  413    414
#  Name: No, Length: 414, dtype: int64]

# %%
dataSet['Y house price of unit area'][10] # Accessing particular values
# Out:
# 41.4

# %%
print(type(dataSet[['No']])) #checking the type of dataSet
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
dataSet[['No','X2 house age']] #Multiple column accessing/ Dataframe creation of multiple columns
# Out:
#       No  X2 house age
# 0      1          32.0
# 1      2          19.5
# 2      3          13.3
# 3      4          13.3
# 4      5           5.0
# ..   ...           ...
# 409  410          13.7
# 410  411           5.6
# 411  412          18.8
# 412  413           8.1
# 413  414           6.5
#
# [414 rows x 2 columns]

# %%
#Considering header as a data values
d1 = pd.read_csv('C:/Users/ADMIN/Desktop/Data Science/Real estate/Real estate.csv',header = None)
d1
# Out:
#        0                    1             2  \
# 0     No  X1 transaction date  X2 house age
# 1      1             2012.917            32
# 2      2             2012.917          19.5
# 3      3             2013.583          13.3
# 4      4             2013.500          13.3
# ..   ...                  ...           ...
# 410  410             2013.000          13.7
# 411  411             2012.667           5.6
# 412  412             2013.250          18.8
# 413  413             2013.000           8.1
# 414  414             2013.500           6.5
#
#                                           3                                4  \
# 0    X3 distance to the nearest MRT station  X4 number of convenience stores
# 1                                  84.87882                               10
# 2                                  306.5947                                9
# 3                                  561.9845                                5
# ...

# %%
#Skiprows -- Skip the row of particular index in the dataSet
d1 = pd.read_csv('C:/Users/ADMIN/Desktop/Data Science/Real estate/Real estate.csv',header = None, skiprows = 1)
d1
# Out:
#        0         1     2           3   4         5          6     7
# 0      1  2012.917  32.0    84.87882  10  24.98298  121.54024  37.9
# 1      2  2012.917  19.5   306.59470   9  24.98034  121.53951  42.2
# 2      3  2013.583  13.3   561.98450   5  24.98746  121.54391  47.3
# 3      4  2013.500  13.3   561.98450   5  24.98746  121.54391  54.8
# 4      5  2012.833   5.0   390.56840   5  24.97937  121.54245  43.1
# ..   ...       ...   ...         ...  ..       ...        ...   ...
# 409  410  2013.000  13.7  4082.01500   0  24.94155  121.50381  15.4
# 410  411  2012.667   5.6    90.45606   9  24.97433  121.54310  50.0
# 411  412  2013.250  18.8   390.96960   7  24.97923  121.53986  40.6
# 412  413  2013.000   8.1   104.81010   5  24.96674  121.54067  52.5
# 413  414  2013.500   6.5    90.45606   9  24.97433  121.54310  63.9
#
# [414 rows x 8 columns]

# %%
#Skiprows -- Skip the row of particular index in the dataSet
d1 = pd.read_csv('C:/Users/ADMIN/Desktop/Data Science/Real estate/Real estate.csv',header = None,skiprows = [3])
d1
# Out:
#        0                    1             2  \
# 0     No  X1 transaction date  X2 house age
# 1      1             2012.917            32
# 2      2             2012.917          19.5
# 3      4             2013.500          13.3
# 4      5             2012.833             5
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#                                           3                                4  \
# 0    X3 distance to the nearest MRT station  X4 number of convenience stores
# 1                                  84.87882                               10
# 2                                  306.5947                                9
# 3                                  561.9845                                5
# ...

# %%
#Assigning header by using list of names
dataSet = pd.read_csv('C:/Users/ADMIN/Desktop/Data Science/Real estate/Real estate.csv',header = None,names = ['Sl.No','Date','House Age','Nearest to MTR station','Nearest stores','Lattitude','Longitude','Price per unit area'],skiprows = 1)
dataSet
# Out:
#      Sl.No      Date  House Age  Nearest to MTR station  Nearest stores  \
# 0        1  2012.917       32.0                84.87882              10
# 1        2  2012.917       19.5               306.59470               9
# 2        3  2013.583       13.3               561.98450               5
# 3        4  2013.500       13.3               561.98450               5
# 4        5  2012.833        5.0               390.56840               5
# ..     ...       ...        ...                     ...             ...
# 409    410  2013.000       13.7              4082.01500               0
# 410    411  2012.667        5.6                90.45606               9
# 411    412  2013.250       18.8               390.96960               7
# 412    413  2013.000        8.1               104.81010               5
# 413    414  2013.500        6.5                90.45606               9
#
#      Lattitude  Longitude  Price per unit area
# 0     24.98298  121.54024                 37.9
# ...

# %%
d1 = pd.read_csv('C:/Users/ADMIN/Desktop/Data Science/Real estate/Real estate.csv',na_values=[0])

# %%
d1.to_csv('file_check1.csv')

# %%
d1.to_csv('file_check1.csv',sep = '@')

# %%
d1.to_csv('file_check1.csv',index = False,header = False)

# %% [markdown]
# # Reading tabular data

# %%
df = pd.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df = pd.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv',header = None,names= [1,2,3,4,5])

# %%
df
# Out:
#              1         2                                      3  \
# 0     order_id  quantity                              item_name
# 1            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                                   Izze
# 3            1         1                       Nantucket Nectar
# 4            1         1  Chips and Tomatillo-Green Chili Salsa
# ...        ...       ...                                    ...
# 4618      1833         1                          Steak Burrito
# 4619      1833         1                          Steak Burrito
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
# 4622      1834         1                     Chicken Salad Bowl
#
#                                                       4           5
# 0                                    choice_description  item_price
# ...

# %%
df[1]
# Out:
# 0       order_id
# 1              1
# 2              1
# 3              1
# 4              1
#           ...
# 4618        1833
# 4619        1833
# 4620        1834
# 4621        1834
# 4622        1834
# Name: 1, Length: 4623, dtype: object

# %%
df['new'] = df[1] + df[2]
df['new']
# Out:
# 0       order_idquantity
# 1                     11
# 2                     11
# 3                     11
# 4                     11
#               ...
# 4618               18331
# 4619               18331
# 4620               18341
# 4621               18341
# 4622               18341
# Name: new, Length: 4623, dtype: object

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df.describe(include = 'all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
df.describe(include = 'int64')
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df.describe(include = 'object')
# Out:
#            item_name choice_description item_price
# count           4622               3376       4622
# unique            50               1043         78
# top     Chicken Bowl        [Diet Coke]     $8.75
# freq             726                134        730

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.rename(columns ={'order_id':'order id'})
# Out:
#       order id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.rename(columns ={'order_id':'order id'},inplace = True)

# %%
df
# Out:
#       order id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.columns = df.columns.str.replace('_','__')

# %%
df
# Out:
#       order id  quantity                             item__name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                     choice__description item__price
# 0                                                   NaN      $2.39
# ...
